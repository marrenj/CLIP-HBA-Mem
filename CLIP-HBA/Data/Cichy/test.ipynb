# %%
import pandas as pd

path = './cichy_118_images_list.csv'

df = pd.read_csv(path)
df
# Out:
#      index       image_name
# 0        0  stimulus001.png
# 1        1  stimulus002.png
# 2        2  stimulus003.png
# 3        3  stimulus004.png
# 4        4  stimulus005.png
# ..     ...              ...
# 113    113  stimulus114.png
# 114    114  stimulus115.png
# 115    115  stimulus116.png
# 116    116  stimulus117.png
# 117    117  stimulus118.png
#
# [118 rows x 2 columns]

# %%
df_train = df.iloc[:100]
df_val = df.iloc[100:]

df_train.to_csv('./cichy_100_images_list_train.csv', index=False)
df_val.to_csv('./cichy_18_images_list_val.csv', index=False)
