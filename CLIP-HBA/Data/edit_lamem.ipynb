# %%
import pandas as pd

for split in ['test']:
    for num in range(1, 6):
        df = pd.read_csv(f'./lamem/splits/{split}_{num}.txt', sep=' ', header=None, names=['image_path', 'score'])
        df.to_csv(f'./lamem/lamem_{split}_{num}.csv', index=False)
